# %%
# Find the shows. Write to shows.json.
import requests
import json
import os

# %%
# URL to the PBS Kids Shows API
PBSKIDS_SHOWS = "http://pbskids.org/pbsk/video/api/getShows/"
PBSKIDS_VIDS = "http://pbskids.org/pbsk/video/api/getVideos/"

SHOWS_CACHE = "shows.json"
VIDEOS_CACHE = "videos.json"

# %%
# Cache file to avoid hitting PBSKids.org more than once for testing
# If the file exists
if os.path.exists(SHOWS_CACHE):
    print("Loading shows from cache...")
    # Load it.
    with open(SHOWS_CACHE, 'r') as infile:
        shows_result=json.load(infile)
else:
    print("Loading shows from web...")
    # Otherwise get the response from the URL.
    resp = requests.get(PBSKIDS_SHOWS)
    shows_result = json.loads(resp.text)
    # Cache the shows.
    with open(SHOWS_CACHE, 'w') as outfile:
        json.dump(shows_result, outfile)
    # Reload from the file, just to be sure.
    with open(SHOWS_CACHE, 'r') as infile:
        shows_result2 = json.load(infile)
    # Assert that the loaded cache works.
    assert shows_result == shows_result2
# Out:
# Loading shows from web...

# %%
# Assert that the number of shows it says it returned matches the number of entries returned
shows=shows_result["items"]
assert len(shows) ==   shows_result["count"]
# Print off all of the shows
print("Found Shows: ")
for show in shows:
    try:
        print("    \"{title} {cove_slug} [{nola}]\"".format(**show))
    except:
        print("    \"{title} [{nola}]\"".format(**show))
# Out:
# Found Shows:
#     "Arthur arthur [ARUR]"
#     "Bob the Builder bob-builder [BOBL]"
#     "Caillou caillou [CAIU]"
#     "Chuck Vanderchuck chuck-vanderchuck [CHUV]"
#     "Clifford the Big Red Dog clifford-big-red-dog [CBDG]"
#     "Clifford's Puppy Days [CPUP]"
#     "Curious George curious-george [CUGE]"
#     "Cyberchase cyberchase [CYBR]"
#     "Daniel Tiger's Neighborhood daniel-tigers-neighborhood [DTIG]"
#     "Design Squad design-squad-nation [DESQ]"
#     "Dinosaur Train dinosaur-train [DINS]"
#     "Dot's Spot  []"
#     "FETCH! with Ruff Ruffman fetch-with-ruff-ruffman [FCTH]"
#     "Fizzy's Lunch Lab fizzys-lunch-lab [FIZL]"
#     "Martha Speaks martha-speaks [MSPE]"
#     "Maya & Miguel maya-miguel [MAYM]"
#     "Nature Cat nature-cat [NCAT]"
#     "Odd Squad ODDS [ODDS]"
#     "Oh Noah! oh-noah [NOAC]"
#     "Peep and the Big Wide World [PEEP]"
#     "Peg + Cat peg [PCAT]"
#     "Pinkalicious and Peterrific [PIPE]"
#     "Plum Landing plum-landing [PLUM]"
#     "Ready Jet Go ready-jet-go [RJGO]"
#     "Room on the Broom [ROOB]"
#     "Ruff Ruffman RUFF [RUFF]"
#     "SciGirls scigirls [SGIR]"
#     "Sesame Street sesame-street [SESA]"
#     "Sid the Science Kid sid-science-kid [SISK]"
#     "Splash and Bubbles splash-bubbles [SBUB]"
#     "Stick Man [SMAN]"
#     "SUPER WHY! super-why [SWHY]"
#     "The Cat in the Hat cat-in-the-hat [CITH]"
#     "The Electric Company electric-company [ELCO]"
#     "The Gruffalo [GRUF]"
#     "The Gruffalo’s Child [GRUC]"
#     "The Ruff Ruffman Show ruff-ruffman-show [RUFR]"
#     "Thomas & Friends thomas-friends [THOF]"
#     "What's Good?  []"
#     "Wild Kratts wild-kratts [WILK]"
#     "Wilson & Ditch Digging America wilson-ditch-digging-america [WDDG]"
#     "Word World word-world [WOWO]"
#     "WordGirl wordgirl [WORG]"

# %%
resp.status_code
# Out:
# 200

# %%
# Create list of all videos
all_videos = list()
# Start index
start_index = 1
# To bootstrap the while loop.
total_videos = start_index + 1  
# While our start index is less than the total number of videos
#while start_index < total_videos:
# Only get full episodes. Can be of type 'Episode' or 'Clip'.
resp = requests.get(
    url=PBSKIDS_VIDS,
    params={
        'page_size': '2',
    }
)
assert(resp.status_code==200)

# %%
https://producerplayer.services.pbskids.org/show-list/?shows=curious-george&shows_title=Curious+George&page=1&page_size=20&available=public&sort=-encored_on

# %%
resp.json()
# Out:
# {'items': [{'type': 'Episode',
#    'links': {'self': 'https://media.services.pbs.org/api/v1/assets/a6512384-9d97-49db-8aa7-1798dceda1a4/'},
#    'id': 'a6512384-9d97-49db-8aa7-1798dceda1a4',
#    'slug': 'super-why-goldilocks-and-three-bears',
#    'title': 'Goldilocks and the Three Bears',
#    'title_sortable': 'Goldilocks and the Three Bears ',
#    'description_short': 'The Super Readers pay a storybook visit to Goldilocks and the Three Bears.',
#    'description_long': "Whyatt accidentally messes up Jack's room and is in BIG trouble with his big brother! The Super Readers pay a storybook visit to Goldilocks and the Three Bears and find Goldilocks surrounded by three broken chairs, three bowls of porridge and three times the mess! How will they solve this problem before the bears get home?",
#    'object_type': 'full_length',
#    'premiered_on': '2007-09-03',
#    'encored_on': '2018-08-03',
#    'is_excluded_from_dfp': False,
#    'duration': 1526,
#    'content_rating': 'TV-Y',
#    'content_rating_descriptor': [],
#    'legacy_tp_media_id': 2365634342,
#    'can_embed_player': False,
#    'tags': ['super why',
#     'super',
#     'why',
#     'whyatt',
#     'brother',
#     'room',
#     'jack',
#     'trouble',
#     'big brother',
#     'siblings',
#     'argue',
#     'super readers',
#     'readers',
#     'read',
#     'reading',
#     'storybook',
#     'goldilocks',
#     'bear',
#     'bears',
#     'three bears',
#     'goldilocks and the three bears',
#     'solve problem solving',
#     'alphabet',
#     'letter',
#     'letters',
#     'spell',
#     'spelling',
#     'vocabulary',
#     'full episode',
#     'full episodes',
#     'episode',
#     'episodes'],
#    'language': 'en',
#    'funder_message': '',
#    'images': {'kids-mezzannine-4x3': {'profile': 'asset-kids-mezzanine-4x3',
#      'updated_at': '2017-04-25T07:30:18.227356Z',
#      'url': 'https://image.pbs.org/video-assets/pbs-kids/super-why/200236/images/kids-mezzannine-4x3_123.jpg'},
#     'kids-mezzannine-16x9': {'profile': 'asset-kids-mezzanine1-16x9',
#      'updated_at': '2017-04-25T07:30:18.227356Z',
#      'url': 'https://image.pbs.org/video-assets/pbs-kids/super-why/200236/images/kids-mezzannine-16x9_514.jpg'},
#     'thumbnailkidsgodefault': {'profile': 'thumbnailkidsgodefault',
#      'url': 'https://image.pbs.org/video-assets/pbs-kids/super-why/200236/images/kids-mezzannine-4x3_123.jpg.resize.69x53.png'},
#     'googlethumbnail': {'profile': 'googlethumbnail',
#      'url': 'https://image.pbs.org/video-assets/pbs-kids/super-why/200236/images/kids-mezzannine-4x3_123.jpg.resize.160x120.png'}},
#    'updated_at': '2018-08-03T21:56:15.378765Z',
#    'countries': [{'name': 'United States',
#      'code': 'US',
#      'updated_at': '2017-04-04T09:00:32.190936Z',
#      'id': '6a9df090-8ede-44c0-8781-5ddbb942966b'},
#     {'name': 'Northern Mariana Islands',
#      'code': 'MP',
#      'updated_at': '2017-04-04T09:00:32.372517Z',
#      'id': '9a9c8e4e-a700-4713-85f4-b3ee31a27879'},
#     {'name': 'Puerto Rico',
#      'code': 'PR',
#      'updated_at': '2017-04-04T09:00:32.377009Z',
#      'id': 'f3c41bf8-f17c-4b55-a540-0e74c80c2cce'},
#     {'name': 'American Samoa',
#      'code': 'AS',
#      'updated_at': '2017-04-04T09:00:32.381542Z',
#      'id': 'c54cfde7-42cb-49df-bb72-d355332d50c9'},
#     {'name': 'Guam',
#      'code': 'GU',
#      'updated_at': '2017-04-04T09:00:32.386117Z',
#      'id': '4f9b354c-7ada-4d83-9085-fcb6c887a5b5'},
#     {'name': 'U.S. Virgin Islands',
#      'code': 'VI',
#      'updated_at': '2017-04-04T09:00:32.390727Z',
#      'id': 'eefe903e-3af4-4b31-a796-3a4b6dd19214'},
#     {'name': 'U.S. Minor Outlying Islands',
#      'code': 'UM',
#      'updated_at': '2017-04-04T09:00:32.395225Z',
#      'id': 'cf58f575-b194-48e3-8700-1086909ed0e1'}],
#    'geo_profile': {'name': 'US & Territories',
#     'updated_at': '2017-04-04T09:00:32.641361Z',
#     'id': 'c94e2e6d-0052-493a-a67d-266d51cc6445'},
#    'topics': [{'name': 'Language & Literacy',
#      'updated_at': '2017-04-04T09:00:06.191403Z',
#      'parent': None,
#      'id': '5a28478e-a056-4e4d-9585-e32e7abf62c8'},
#     {'name': 'Social Skills',
#      'updated_at': '2017-04-04T09:00:06.363438Z',
#      'parent': None,
#      'id': 'f01c4209-0594-49b1-9ec5-09fd4d6fa037'},
#     {'name': 'Emotional Growth',
#      'updated_at': '2017-04-04T09:00:06.368494Z',
#      'parent': None,
#      'id': '8a05d738-b9c8-4d1c-88ce-06ae3bf0abc2'},
#     {'name': 'Alphabet',
#      'updated_at': '2017-04-04T09:00:07.262726Z',
#      'parent': {'name': 'Language & Literacy',
#       'updated_at': '2017-04-04T09:00:06.191403Z',
#       'id': '5a28478e-a056-4e4d-9585-e32e7abf62c8'},
#      'id': 'faebae98-19e0-4421-9373-324d3c1832b1'},
#     {'name': 'Storytelling',
#      'updated_at': '2017-04-04T09:00:07.267839Z',
#      'parent': {'name': 'Language & Literacy',
#       'updated_at': '2017-04-04T09:00:06.191403Z',
#       'id': '5a28478e-a056-4e4d-9585-e32e7abf62c8'},
#      'id': '850a6923-e75d-46af-b7d6-cafce0332919'},
#     {'name': 'Spelling',
#      'updated_at': '2017-04-04T09:00:07.283241Z',
#      'parent': {'name': 'Language & Literacy',
#       'updated_at': '2017-04-04T09:00:06.191403Z',
#       'id': '5a28478e-a056-4e4d-9585-e32e7abf62c8'},
#      'id': '63a8e72a-983a-4a58-a520-152ade6dd096'},
#     {'name': 'Vocabulary',
#      'updated_at': '2017-04-04T09:00:07.288389Z',
#      'parent': {'name': 'Language & Literacy',
#       'updated_at': '2017-04-04T09:00:06.191403Z',
#       'id': '5a28478e-a056-4e4d-9585-e32e7abf62c8'},
#      'id': '163ed7e3-9355-40c6-a706-5cc5f9cf1a6f'},
#     {'name': 'Reading',
#      'updated_at': '2017-04-04T09:00:07.308790Z',
#      'parent': {'name': 'Language & Literacy',
#       'updated_at': '2017-04-04T09:00:06.191403Z',
#       'id': '5a28478e-a056-4e4d-9585-e32e7abf62c8'},
#      'id': '37aa5a1a-575e-448a-aa74-1bc1520a26a1'},
#     {'name': 'Conflicts',
#      'updated_at': '2017-04-04T09:00:07.418356Z',
#      'parent': {'name': 'Social Skills',
#       'updated_at': '2017-04-04T09:00:06.363438Z',
#       'id': 'f01c4209-0594-49b1-9ec5-09fd4d6fa037'},
#      'id': '7f566859-31e0-4412-8953-337d58608d88'},
#     {'name': 'Exploring',
#      'updated_at': '2017-04-04T09:00:07.440471Z',
#      'parent': {'name': 'Social Skills',
#       'updated_at': '2017-04-04T09:00:06.363438Z',
#       'id': 'f01c4209-0594-49b1-9ec5-09fd4d6fa037'},
#      'id': '4620aefa-a7b4-4bc1-8df0-39bf8e04d0a1'},
#     {'name': 'Teamwork',
#      'updated_at': '2017-04-04T09:00:07.461966Z',
#      'parent': {'name': 'Social Skills',
#       'updated_at': '2017-04-04T09:00:06.363438Z',
#       'id': 'f01c4209-0594-49b1-9ec5-09fd4d6fa037'},
#      'id': '918c166d-1fd8-43d7-8f8f-ca14f88e24c3'},
#     {'name': 'Friends',
#      'updated_at': '2017-04-04T09:00:07.467564Z',
#      'parent': {'name': 'Social Skills',
#       'updated_at': '2017-04-04T09:00:06.363438Z',
#       'id': 'f01c4209-0594-49b1-9ec5-09fd4d6fa037'},
#      'id': 'e0516347-0e43-47f9-8b07-4eb914c16662'},
#     {'name': 'Family',
#      'updated_at': '2017-04-04T09:00:07.478246Z',
#      'parent': {'name': 'Emotional Growth',
#       'updated_at': '2017-04-04T09:00:06.368494Z',
#       'id': '8a05d738-b9c8-4d1c-88ce-06ae3bf0abc2'},
#      'id': '1f827f74-f2eb-4e7d-a824-0abc10339482'},
#     {'name': 'Growing Up',
#      'updated_at': '2017-04-04T09:00:07.488898Z',
#      'parent': {'name': 'Emotional Growth',
#       'updated_at': '2017-04-04T09:00:06.368494Z',
#       'id': '8a05d738-b9c8-4d1c-88ce-06ae3bf0abc2'},
#      'id': '347fe51d-ce10-4115-9b1d-ece6ab01eedf'},
#     {'name': 'Feelings',
#      'updated_at': '2017-04-04T09:00:07.494218Z',
#      'parent': {'name': 'Emotional Growth',
#       'updated_at': '2017-04-04T09:00:06.368494Z',
#       'id': '8a05d738-b9c8-4d1c-88ce-06ae3bf0abc2'},
#      'id': '4b916fdc-109b-4885-a65e-8cac500c00ff'},
#     {'name': 'Respect',
#      'updated_at': '2017-04-04T09:00:07.515754Z',
#      'parent': {'name': 'Emotional Growth',
#       'updated_at': '2017-04-04T09:00:06.368494Z',
#       'id': '8a05d738-b9c8-4d1c-88ce-06ae3bf0abc2'},
#      'id': 'c41b44fd-1929-4a89-a48a-1735391c5814'}],
#    'platforms': [{'slug': 'allplatforms',
#      'name': 'All Platforms',
#      'updated_at': '2017-04-03T15:57:09.459445Z',
#      'id': 'e5a289b8-01b3-41ce-92c1-3eb5a4e14bc0'}],
#    'player_code': "<iframe  id='partnerPlayer' frameborder='0' marginwidth='0' marginheight='0' scrolling='no' width='100%' height='100%' src='//player.pbs.org/partnerplayer/Dd6-J8kPI-6bP78NOXJBPA==/?topbar=false&end=0&endscreen=true&start=0&autoplay=false' allowfullscreen></iframe>",
#    'availabilities': {'all_members': {'end': '2018-08-31T04:00:59Z',
#      'start': '2018-08-03T04:00:00Z',
#      'updated_at': '2018-08-03T21:17:54.765670Z'},
#     'station_members': {'end': '2018-08-31T04:00:59Z',
#      'start': '2018-08-03T04:00:00Z',
#      'updated_at': '2018-08-03T21:17:54.842915Z'},
#     'public': {'end': '2018-08-31T04:00:59Z',
#      'start': '2018-08-03T04:00:00Z',
#      'updated_at': '2018-08-03T21:17:54.674893Z'}},
#    'related_links': [],
#    'related_promos': [],
#    'parent_tree': {'type': 'episode',
#     'links': {'self': 'https://media.services.pbs.org/api/v1/episodes/f8cccd5b-321c-494d-b3eb-27afebf703b2/'},
#     'attributes': {'slug': 'super-why-goldilocks-and-three-bears',
#      'title': 'Goldilocks and the Three Bears',
#      'season': {'type': 'season',
#       'links': {'self': 'https://media.services.pbs.org/api/v1/seasons/ba10d565-6346-4e2b-a9ed-93f30a2afdde/'},
#       'attributes': {'show': {'type': 'show',
#         'links': {'self': 'https://media.services.pbs.org/api/v1/shows/91a9b9a7-bfe4-4d79-9e35-1a51fd5cbb85/'},
#         'attributes': {'slug': 'super-why',
#          'seasons_count': 3,
#          'display_episode_number': True,
#          'franchise': None,
#          'tracking_ga_event': 'UA-3994472-2',
#          'title': 'SUPER WHY!',
#          'tracking_ga_page': ''},
#         'id': '91a9b9a7-bfe4-4d79-9e35-1a51fd5cbb85'},
#        'title': '',
#        'ordinal': 1},
#       'id': 'ba10d565-6346-4e2b-a9ed-93f30a2afdde'},
#      'ordinal': 6},
#     'id': 'f8cccd5b-321c-494d-b3eb-27afebf703b2'},
#    'has_captions': True,
#    'episode': {'type': 'episode',
#     'links': {'self': 'https://media.services.pbs.org/api/v1/episodes/f8cccd5b-321c-494d-b3eb-27afebf703b2/'},
#     'attributes': {'slug': 'super-why-goldilocks-and-three-bears',
#      'ordinal': 6,
#      'segment': '',
#      'title': 'Goldilocks and the Three Bears',
#      'title_sortable': 'Goldilocks and the Three Bears ',
#      'updated_at': '2018-08-03T21:17:41.634297Z'},
#     'id': 'f8cccd5b-321c-494d-b3eb-27afebf703b2'},
#    'season': None,
#    'show': None,
#    'franchise': None,
#    'chapters': [],
#    'captions': {'webvtt': {'url': 'https://kids.video.cdn.pbs.org/captions/super-why/a6512384-9d97-49db-8aa7-1798dceda1a4/captions/zM0XwK_caption.vtt',
#      'profile': 'WebVTT'},
#     'srt': {'url': 'https://kids.video.cdn.pbs.org/captions/super-why/a6512384-9d97-49db-8aa7-1798dceda1a4/captions/33WQOb_caption.srt',
#      'profile': 'SRT'},
#     'dfxp': {'url': 'https://kids.video.cdn.pbs.org/captions/super-why/a6512384-9d97-49db-8aa7-1798dceda1a4/captions/fHmzpb_caption.dfxp',
#      'profile': 'DFXP'},
#     'caption-sami': {'url': 'https://kids.video.cdn.pbs.org/captions/super-why/a6512384-9d97-49db-8aa7-1798dceda1a4/captions/jOTOX0_caption.sami',
#      'profile': 'Caption-SAMI'}},
#    'videos': [{'url': 'https://urs.pbs.org/redirect/01988fb793e049b99b570d5e9db52b3e/',
#      'profile': 'hls-16x9-1080p',
#      'format': 'hls',
#      'ratio': '16x9',
#      'bitrate': '1080p'},
#     {'url': 'https://urs.pbs.org/redirect/165a502bcc3c48c38e182ad435909cc6/',
#      'profile': 'hls-16x9-720p',
#      'format': 'hls',
#      'ratio': '16x9',
#      'bitrate': '720p'},
#     {'url': 'https://urs.pbs.org/redirect/6a89f44e3e674922bbecca962d419a78/',
#      'profile': 'mp4-16x9-baseline',
#      'format': 'mp4',
#      'ratio': '16x9',
#      'bitrate': None},
#     {'url': 'https://urs.pbs.org/redirect/1a6e0595b17449b987408a3f780ecd82/',
#      'profile': 'mp4-16x9-720p',
#      'format': 'mp4',
#      'ratio': '16x9',
#      'bitrate': '720p'}],
#    'series_title': 'SUPER WHY!',
#    'series_slug': 'super-why',
#    'series_nola': 'SWHY',
#    'supports': {'hls': True, 'mp4': True},
#    'guid': 'a6512384-9d97-49db-8aa7-1798dceda1a4',
#    'description': "Whyatt accidentally messes up Jack's room and is in BIG trouble with his big brother! The Super Readers pay a storybook visit to Goldilocks and the Three Bears and find Goldilocks surrounded by three broken chairs, three bowls of porridge and three times the mess! How will they solve this problem before the bears get home?",
#    'keywords': ['super why',
#     'super',
#     'why',
#     'whyatt',
#     'brother',
#     'room',
#     'jack',
#     'trouble',
#     'big brother',
#     'siblings',
#     'argue',
#     'super readers',
#     'readers',
#     'read',
#     'reading',
#     'storybook',
#     'goldilocks',
#     'bear',
#     'bears',
#     'three bears',
#     'goldilocks and the three bears',
#     'solve problem solving',
#     'alphabet',
#     'letter',
#     'letters',
#     'spell',
#     'spelling',
#     'vocabulary',
#     'full episode',
#     'full episodes',
#     'episode',
#     'episodes'],
#    'media_id': 2365634342,
#    'nola_episode': 'SWHY106',
#    'expirationdate': '2018-08-31T04:00:59Z',
#    'availabledate': '2018-08-03T04:00:00Z'},
#   {'type': 'Episode',
#    'links': {'self': 'https://media.services.pbs.org/api/v1/assets/00aa5901-60d2-43b9-911c-17b9e0516aba/'},
#    'id': '00aa5901-60d2-43b9-911c-17b9e0516aba',
#    'slug': 'kite-flighthide-and-seek-33gl7f',
#    'title': 'Kite Flight/Hide and Seek',
#    'title_sortable': 'Kite Flight/Hide and Seek',
#    'description_short': 'When Frog sails away on a big kite he built./The WordFriends play a game of Hide and Seek.',
#    'description_long': 'When Frog sails away on a big kite he built, it\'s up to Duck and Shark to save him./The WordFriends play a game of Hide and Seek where they have to hide behind WordThings that end in "ake."',
#    'object_type': 'full_length',
#    'premiered_on': '2010-10-05',
#    'encored_on': '2018-08-03',
#    'is_excluded_from_dfp': False,
#    'duration': 1563,
#    'content_rating': 'TV-Y',
#    'content_rating_descriptor': [],
#    'legacy_tp_media_id': 3003447447,
#    'can_embed_player': False,
#    'tags': ['word',
#     'world',
#     'wordworld',
#     'frog',
#     'duck',
#     'shark',
#     'sail',
#     'away',
#     'kite',
#     'flight',
#     'fly',
#     'wordfriends',
#     'friend',
#     'play',
#     'game',
#     'hide',
#     'seek',
#     'things',
#     'ake'],
#    'language': 'en',
#    'funder_message': '',
#    'images': {'kids-mezzannine-4x3': {'profile': 'asset-kids-mezzanine-4x3',
#      'updated_at': '2017-08-03T19:29:33.505030Z',
#      'url': 'https://image.pbs.org/video-assets/wUmlUfN-asset-kids-mezzanine-4x3-f389DCh.jpg'},
#     'kids-mezzannine-16x9': {'profile': 'asset-kids-mezzanine1-16x9',
#      'updated_at': '2017-08-03T19:29:26.897296Z',
#      'url': 'https://image.pbs.org/video-assets/U0YY7u9-asset-kids-mezzanine1-16x9-x2WR3qs.jpg'},
#     'thumbnailkidsgodefault': {'profile': 'thumbnailkidsgodefault',
#      'url': 'https://image.pbs.org/video-assets/wUmlUfN-asset-kids-mezzanine-4x3-f389DCh.jpg.resize.69x53.png'},
#     'googlethumbnail': {'profile': 'googlethumbnail',
#      'url': 'https://image.pbs.org/video-assets/wUmlUfN-asset-kids-mezzanine-4x3-f389DCh.jpg.resize.160x120.png'}},
#    'updated_at': '2018-08-02T21:56:36.946473Z',
#    'countries': [{'name': 'United States',
#      'code': 'US',
#      'updated_at': '2017-04-04T09:00:32.190936Z',
#      'id': '6a9df090-8ede-44c0-8781-5ddbb942966b'},
#     {'name': 'Northern Mariana Islands',
#      'code': 'MP',
#      'updated_at': '2017-04-04T09:00:32.372517Z',
#      'id': '9a9c8e4e-a700-4713-85f4-b3ee31a27879'},
#     {'name': 'Puerto Rico',
#      'code': 'PR',
#      'updated_at': '2017-04-04T09:00:32.377009Z',
#      'id': 'f3c41bf8-f17c-4b55-a540-0e74c80c2cce'},
#     {'name': 'American Samoa',
#      'code': 'AS',
#      'updated_at': '2017-04-04T09:00:32.381542Z',
#      'id': 'c54cfde7-42cb-49df-bb72-d355332d50c9'},
#     {'name': 'Guam',
#      'code': 'GU',
#      'updated_at': '2017-04-04T09:00:32.386117Z',
#      'id': '4f9b354c-7ada-4d83-9085-fcb6c887a5b5'},
#     {'name': 'U.S. Virgin Islands',
#      'code': 'VI',
#      'updated_at': '2017-04-04T09:00:32.390727Z',
#      'id': 'eefe903e-3af4-4b31-a796-3a4b6dd19214'},
#     {'name': 'U.S. Minor Outlying Islands',
#      'code': 'UM',
#      'updated_at': '2017-04-04T09:00:32.395225Z',
#      'id': 'cf58f575-b194-48e3-8700-1086909ed0e1'}],
#    'geo_profile': {'name': 'US & Territories',
#     'updated_at': '2017-04-04T09:00:32.641361Z',
#     'id': 'c94e2e6d-0052-493a-a67d-266d51cc6445'},
#    'topics': [{'name': 'Language & Literacy',
#      'updated_at': '2017-04-04T09:00:06.191403Z',
#      'parent': None,
#      'id': '5a28478e-a056-4e4d-9585-e32e7abf62c8'},
#     {'name': 'Alphabet',
#      'updated_at': '2017-04-04T09:00:07.262726Z',
#      'parent': {'name': 'Language & Literacy',
#       'updated_at': '2017-04-04T09:00:06.191403Z',
#       'id': '5a28478e-a056-4e4d-9585-e32e7abf62c8'},
#      'id': 'faebae98-19e0-4421-9373-324d3c1832b1'},
#     {'name': 'Storytelling',
#      'updated_at': '2017-04-04T09:00:07.267839Z',
#      'parent': {'name': 'Language & Literacy',
#       'updated_at': '2017-04-04T09:00:06.191403Z',
#       'id': '5a28478e-a056-4e4d-9585-e32e7abf62c8'},
#      'id': '850a6923-e75d-46af-b7d6-cafce0332919'},
#     {'name': 'Vocabulary',
#      'updated_at': '2017-04-04T09:00:07.288389Z',
#      'parent': {'name': 'Language & Literacy',
#       'updated_at': '2017-04-04T09:00:06.191403Z',
#       'id': '5a28478e-a056-4e4d-9585-e32e7abf62c8'},
#      'id': '163ed7e3-9355-40c6-a706-5cc5f9cf1a6f'},
#     {'name': 'Reading',
#      'updated_at': '2017-04-04T09:00:07.308790Z',
#      'parent': {'name': 'Language & Literacy',
#       'updated_at': '2017-04-04T09:00:06.191403Z',
#       'id': '5a28478e-a056-4e4d-9585-e32e7abf62c8'},
#      'id': '37aa5a1a-575e-448a-aa74-1bc1520a26a1'}],
#    'platforms': [{'slug': 'allplatforms',
#      'name': 'All Platforms',
#      'updated_at': '2017-04-03T15:57:09.459445Z',
#      'id': 'e5a289b8-01b3-41ce-92c1-3eb5a4e14bc0'}],
#    'player_code': "<iframe  id='partnerPlayer' frameborder='0' marginwidth='0' marginheight='0' scrolling='no' width='100%' height='100%' src='//player.pbs.org/partnerplayer/L6prw9LpVjPPKRp3xnrT3A==/?topbar=false&end=0&endscreen=true&start=0&autoplay=false' allowfullscreen></iframe>",
#    'availabilities': {'all_members': {'end': '2018-08-31T04:00:59Z',
#      'start': '2018-08-03T04:00:00Z',
#      'updated_at': '2018-08-02T21:56:28.353697Z'},
#     'station_members': {'end': '2018-08-31T04:00:59Z',
#      'start': '2018-08-03T04:00:00Z',
#      'updated_at': '2018-08-02T21:56:28.412504Z'},
#     'public': {'end': '2018-08-31T04:00:59Z',
#      'start': '2018-08-03T04:00:00Z',
#      'updated_at': '2018-08-02T21:56:28.296865Z'}},
#    'related_links': [],
#    'related_promos': [],
#    'parent_tree': {'type': 'episode',
#     'links': {'self': 'https://media.services.pbs.org/api/v1/episodes/096752d4-4ed5-48f3-b2d6-81c96bcb6eeb/'},
#     'attributes': {'slug': 'kite-flighthide-and-seek-rn2ou0',
#      'title': 'Kite Flight/Hide and Seek',
#      'season': {'type': 'season',
#       'links': {'self': 'https://media.services.pbs.org/api/v1/seasons/1b4f8841-a4fa-400d-96e5-6c78595bbcfb/'},
#       'attributes': {'show': {'type': 'show',
#         'links': {'self': 'https://media.services.pbs.org/api/v1/shows/b3c006f3-90db-4f2c-983a-314ebacf9b88/'},
#         'attributes': {'slug': 'word-world',
#          'seasons_count': 3,
#          'display_episode_number': True,
#          'franchise': None,
#          'tracking_ga_event': 'UA-4000339-2',
#          'title': 'Word World',
#          'tracking_ga_page': ''},
#         'id': 'b3c006f3-90db-4f2c-983a-314ebacf9b88'},
#        'title': '',
#        'ordinal': 3},
#       'id': '1b4f8841-a4fa-400d-96e5-6c78595bbcfb'},
#      'ordinal': 2},
#     'id': '096752d4-4ed5-48f3-b2d6-81c96bcb6eeb'},
#    'has_captions': True,
#    'episode': {'type': 'episode',
#     'links': {'self': 'https://media.services.pbs.org/api/v1/episodes/096752d4-4ed5-48f3-b2d6-81c96bcb6eeb/'},
#     'attributes': {'slug': 'kite-flighthide-and-seek-rn2ou0',
#      'ordinal': 2,
#      'segment': '',
#      'title': 'Kite Flight/Hide and Seek',
#      'title_sortable': 'Kite Flight/Hide and Seek',
#      'updated_at': '2018-08-02T21:56:20.476411Z'},
#     'id': '096752d4-4ed5-48f3-b2d6-81c96bcb6eeb'},
#    'season': None,
#    'show': None,
#    'franchise': None,
#    'chapters': [],
#    'captions': {'srt': {'profile': 'SRT',
#      'url': 'http://kids.video.cdn.pbs.org/captions/word-world/00aa5901-60d2-43b9-911c-17b9e0516aba/captions/X87vOo_caption.srt'},
#     'webvtt': {'profile': 'WebVTT',
#      'url': 'http://kids.video.cdn.pbs.org/captions/word-world/00aa5901-60d2-43b9-911c-17b9e0516aba/captions/yljpmL_caption.vtt'},
#     'caption-sami': {'profile': 'Caption-SAMI',
#      'url': 'http://kids.video.cdn.pbs.org/captions/word-world/00aa5901-60d2-43b9-911c-17b9e0516aba/captions/ofukCW_caption.sami'},
#     'dfxp': {'profile': 'DFXP',
#      'url': 'http://kids.video.cdn.pbs.org/captions/word-world/00aa5901-60d2-43b9-911c-17b9e0516aba/captions/xVcAKK_caption.dfxp'}},
#    'videos': [{'profile': 'hls-16x9-1080p',
#      'url': 'https://urs.pbs.org/redirect/3b5dd97ce33544b2b84bbc5594d2a9cf/',
#      'format': 'hls',
#      'ratio': '16x9',
#      'bitrate': '1080p'},
#     {'profile': 'hls-16x9-720p',
#      'url': 'https://urs.pbs.org/redirect/d02ced045589482e868d7f60ec9fd063/',
#      'format': 'hls',
#      'ratio': '16x9',
#      'bitrate': '720p'},
#     {'profile': 'mp4-16x9-baseline',
#      'url': 'https://urs.pbs.org/redirect/629be13dcd9f468c8473caed9935f983/',
#      'format': 'mp4',
#      'ratio': '16x9',
#      'bitrate': None},
#     {'profile': 'mp4-16x9-720p',
#      'url': 'https://urs.pbs.org/redirect/9cb27e915bb945e685e21da3dad8107c/',
#      'format': 'mp4',
#      'ratio': '16x9',
#      'bitrate': '720p'}],
#    'series_title': 'Word World',
#    'series_slug': 'word-world',
#    'series_nola': 'WOWO',
#    'supports': {'hls': True, 'mp4': True},
#    'guid': '00aa5901-60d2-43b9-911c-17b9e0516aba',
#    'description': 'When Frog sails away on a big kite he built, it\'s up to Duck and Shark to save him./The WordFriends play a game of Hide and Seek where they have to hide behind WordThings that end in "ake."',
#    'keywords': ['word',
#     'world',
#     'wordworld',
#     'frog',
#     'duck',
#     'shark',
#     'sail',
#     'away',
#     'kite',
#     'flight',
#     'fly',
#     'wordfriends',
#     'friend',
#     'play',
#     'game',
#     'hide',
#     'seek',
#     'things',
#     'ake'],
#    'media_id': 3003447447,
#    'nola_episode': 'WOWO302',
#    'expirationdate': '2018-08-31T04:00:59Z',
#    'availabledate': '2018-08-03T04:00:00Z'},
#   {'type': 'Episode',
#    'links': {'self': 'https://media.services.pbs.org/api/v1/assets/404112b3-0c95-48a2-b608-98e97f8f9217/'},
#    'id': '404112b3-0c95-48a2-b608-98e97f8f9217',
#    'slug': 'wordgirl-sticky-situationeight-legs-vs-two-brains',
#    'title': 'A Sticky Situation/Eight Legs vs. Two Brains',
#    'title_sortable': 'A Sticky Situation/Eight Legs vs. Two Brains',
#    'description_short': 'WordGirl and TJ becoming glued together. / Becky has to take home the class pet',
#    'description_long': 'WordGirl and TJ becoming glued together. / Becky has to take home the class pet',
#    'object_type': 'full_length',
#    'premiered_on': '2015-06-12',
#    'encored_on': '2018-08-03',
#    'is_excluded_from_dfp': False,
#    'duration': 1585,
#    'content_rating': 'TV-Y',
#    'content_rating_descriptor': [],
#    'legacy_tp_media_id': 2365490963,
#    'can_embed_player': False,
#    'tags': ['wordgirl',
#     'word girl',
#     'literacy',
#     'learning',
#     'words',
#     'word',
#     'educate',
#     'define',
#     'becky',
#     'botsford',
#     'education',
#     'superpowers',
#     'superhero'],
#    'language': 'en',
#    'funder_message': '',
#    'images': {'kids-mezzannine-4x3': {'profile': 'asset-kids-mezzanine-4x3',
#      'updated_at': '2017-04-25T07:30:18.227356Z',
#      'url': 'https://image.pbs.org/video-assets/pbs-kids/wordgirl/173653/images/kids-mezzannine-4x3_835.jpg'},
#     'kids-mezzannine-16x9': {'profile': 'asset-kids-mezzanine1-16x9',
#      'updated_at': '2017-04-25T07:30:18.227356Z',
#      'url': 'https://image.pbs.org/video-assets/pbs-kids/wordgirl/173653/images/kids-mezzannine-16x9_737.jpg'},
#     'thumbnailkidsgodefault': {'profile': 'thumbnailkidsgodefault',
#      'url': 'https://image.pbs.org/video-assets/pbs-kids/wordgirl/173653/images/kids-mezzannine-4x3_835.jpg.resize.69x53.png'},
#     'googlethumbnail': {'profile': 'googlethumbnail',
#      'url': 'https://image.pbs.org/video-assets/pbs-kids/wordgirl/173653/images/kids-mezzannine-4x3_835.jpg.resize.160x120.png'}},
#    'updated_at': '2018-08-02T21:55:46.362248Z',
#    'countries': [{'name': 'United States',
#      'code': 'US',
#      'updated_at': '2017-04-04T09:00:32.190936Z',
#      'id': '6a9df090-8ede-44c0-8781-5ddbb942966b'},
#     {'name': 'Northern Mariana Islands',
#      'code': 'MP',
#      'updated_at': '2017-04-04T09:00:32.372517Z',
#      'id': '9a9c8e4e-a700-4713-85f4-b3ee31a27879'},
#     {'name': 'Puerto Rico',
#      'code': 'PR',
#      'updated_at': '2017-04-04T09:00:32.377009Z',
#      'id': 'f3c41bf8-f17c-4b55-a540-0e74c80c2cce'},
#     {'name': 'American Samoa',
#      'code': 'AS',
#      'updated_at': '2017-04-04T09:00:32.381542Z',
#      'id': 'c54cfde7-42cb-49df-bb72-d355332d50c9'},
#     {'name': 'Guam',
#      'code': 'GU',
#      'updated_at': '2017-04-04T09:00:32.386117Z',
#      'id': '4f9b354c-7ada-4d83-9085-fcb6c887a5b5'},
#     {'name': 'U.S. Virgin Islands',
#      'code': 'VI',
#      'updated_at': '2017-04-04T09:00:32.390727Z',
#      'id': 'eefe903e-3af4-4b31-a796-3a4b6dd19214'},
#     {'name': 'U.S. Minor Outlying Islands',
#      'code': 'UM',
#      'updated_at': '2017-04-04T09:00:32.395225Z',
#      'id': 'cf58f575-b194-48e3-8700-1086909ed0e1'}],
#    'geo_profile': {'name': 'US & Territories',
#     'updated_at': '2017-04-04T09:00:32.641361Z',
#     'id': 'c94e2e6d-0052-493a-a67d-266d51cc6445'},
#    'topics': [{'name': 'Language & Literacy',
#      'updated_at': '2017-04-04T09:00:06.191403Z',
#      'parent': None,
#      'id': '5a28478e-a056-4e4d-9585-e32e7abf62c8'},
#     {'name': 'Social Skills',
#      'updated_at': '2017-04-04T09:00:06.363438Z',
#      'parent': None,
#      'id': 'f01c4209-0594-49b1-9ec5-09fd4d6fa037'},
#     {'name': 'Emotional Growth',
#      'updated_at': '2017-04-04T09:00:06.368494Z',
#      'parent': None,
#      'id': '8a05d738-b9c8-4d1c-88ce-06ae3bf0abc2'},
#     {'name': 'Storytelling',
#      'updated_at': '2017-04-04T09:00:07.267839Z',
#      'parent': {'name': 'Language & Literacy',
#       'updated_at': '2017-04-04T09:00:06.191403Z',
#       'id': '5a28478e-a056-4e4d-9585-e32e7abf62c8'},
#      'id': '850a6923-e75d-46af-b7d6-cafce0332919'},
#     {'name': 'Vocabulary',
#      'updated_at': '2017-04-04T09:00:07.288389Z',
#      'parent': {'name': 'Language & Literacy',
#       'updated_at': '2017-04-04T09:00:06.191403Z',
#       'id': '5a28478e-a056-4e4d-9585-e32e7abf62c8'},
#      'id': '163ed7e3-9355-40c6-a706-5cc5f9cf1a6f'},
#     {'name': 'Teamwork',
#      'updated_at': '2017-04-04T09:00:07.461966Z',
#      'parent': {'name': 'Social Skills',
#       'updated_at': '2017-04-04T09:00:06.363438Z',
#       'id': 'f01c4209-0594-49b1-9ec5-09fd4d6fa037'},
#      'id': '918c166d-1fd8-43d7-8f8f-ca14f88e24c3'}],
#    'platforms': [{'slug': 'allplatforms',
#      'name': 'All Platforms',
#      'updated_at': '2017-04-03T15:57:09.459445Z',
#      'id': 'e5a289b8-01b3-41ce-92c1-3eb5a4e14bc0'}],
#    'player_code': "<iframe  id='partnerPlayer' frameborder='0' marginwidth='0' marginheight='0' scrolling='no' width='100%' height='100%' src='//player.pbs.org/partnerplayer/zXJRM8HIuAFC9DDLUhGf4A==/?topbar=false&end=0&endscreen=true&start=0&autoplay=false' allowfullscreen></iframe>",
#    'availabilities': {'all_members': {'end': '2018-08-31T04:00:59Z',
#      'start': '2018-08-03T04:00:00Z',
#      'updated_at': '2018-08-02T21:55:28.119967Z'},
#     'station_members': {'end': '2018-08-31T04:00:59Z',
#      'start': '2018-08-03T04:00:00Z',
#      'updated_at': '2018-08-02T21:55:28.172308Z'},
#     'public': {'end': '2018-08-31T04:00:59Z',
#      'start': '2018-08-03T04:00:00Z',
#      'updated_at': '2018-08-02T21:55:28.060688Z'}},
#    'related_links': [],
#    'related_promos': [],
#    'parent_tree': {'type': 'episode',
#     'links': {'self': 'https://media.services.pbs.org/api/v1/episodes/2cda3416-296b-4f41-9345-150e7a3c1dfd/'},
#     'attributes': {'slug': 'wordgirl-sticky-situationeight-legs-vs-two-brains',
#      'title': 'A Sticky Situation/Eight Legs vs. Two Brains',
#      'season': {'type': 'season',
#       'links': {'self': 'https://media.services.pbs.org/api/v1/seasons/294ecb28-b770-40ea-a49b-050c90d0993d/'},
#       'attributes': {'show': {'type': 'show',
#         'links': {'self': 'https://media.services.pbs.org/api/v1/shows/bb427573-f353-42fc-9be3-a599dc715feb/'},
#         'attributes': {'slug': 'wordgirl',
#          'seasons_count': 8,
#          'display_episode_number': True,
#          'franchise': None,
#          'tracking_ga_event': 'UA-3999648-2',
#          'title': 'WordGirl',
#          'tracking_ga_page': ''},
#         'id': 'bb427573-f353-42fc-9be3-a599dc715feb'},
#        'title': '',
#        'ordinal': 8},
#       'id': '294ecb28-b770-40ea-a49b-050c90d0993d'},
#      'ordinal': 8},
#     'id': '2cda3416-296b-4f41-9345-150e7a3c1dfd'},
#    'has_captions': True,
#    'episode': {'type': 'episode',
#     'links': {'self': 'https://media.services.pbs.org/api/v1/episodes/2cda3416-296b-4f41-9345-150e7a3c1dfd/'},
#     'attributes': {'slug': 'wordgirl-sticky-situationeight-legs-vs-two-brains',
#      'ordinal': 8,
#      'segment': '',
#      'title': 'A Sticky Situation/Eight Legs vs. Two Brains',
#      'title_sortable': 'A Sticky Situation/Eight Legs vs. Two Brains',
#      'updated_at': '2018-08-02T21:55:19.829204Z'},
#     'id': '2cda3416-296b-4f41-9345-150e7a3c1dfd'},
#    'season': None,
#    'show': None,
#    'franchise': None,
#    'chapters': [],
#    'captions': {'caption-sami': {'profile': 'Caption-SAMI',
#      'url': 'http://kids.video.cdn.pbs.org/captions/wordgirl/404112b3-0c95-48a2-b608-98e97f8f9217/captions/329705_Encoded.sami'},
#     'dfxp': {'profile': 'DFXP',
#      'url': 'http://kids.video.cdn.pbs.org/captions/wordgirl/404112b3-0c95-48a2-b608-98e97f8f9217/captions/329706_Encoded.dfxp'},
#     'srt': {'profile': 'SRT',
#      'url': 'http://kids.video.cdn.pbs.org/captions/wordgirl/404112b3-0c95-48a2-b608-98e97f8f9217/captions/329707_Encoded.srt'},
#     'webvtt': {'profile': 'WebVTT',
#      'url': 'http://kids.video.cdn.pbs.org/captions/wordgirl/404112b3-0c95-48a2-b608-98e97f8f9217/captions/329708_Encoded.vtt'}},
#    'videos': [{'profile': 'mp4-baseline-16x9',
#      'url': 'http://urs.pbs.org/redirect/a25937aa110f438e9b9bdc1e77022cfd/',
#      'format': 'mp4',
#      'ratio': '16x9',
#      'bitrate': None},
#     {'profile': 'ipad-16x9',
#      'url': 'http://urs.pbs.org/redirect/382ed93126864a16bd3f06f94d41a782/'},
#     {'profile': 'hls-1200k-16x9',
#      'url': 'http://urs.pbs.org/redirect/016c2ded277c47a68776f5fa7cbff0be/',
#      'format': 'hls',
#      'ratio': '16x9',
#      'bitrate': '1200k'},
#     {'profile': 'mp4-800k-16x9',
#      'url': 'http://urs.pbs.org/redirect/ac60db698b6446038425279aaaa0b7c2/',
#      'format': 'mp4',
#      'ratio': '16x9',
#      'bitrate': '800k'},
#     {'profile': 'mp4-400k-16x9',
#      'url': 'http://urs.pbs.org/redirect/75114fff2a3349668fd150e0731e198b/',
#      'format': 'mp4',
#      'ratio': '16x9',
#      'bitrate': '400k'},
#     {'profile': 'mp4-2500k-16x9',
#      'url': 'http://urs.pbs.org/redirect/5e27f1f4764c45cb8f542e54427fe726/',
#      'format': 'mp4',
#      'ratio': '16x9',
#      'bitrate': '2500k'},
#     {'profile': 'mp4-1200k-16x9',
#      'url': 'http://urs.pbs.org/redirect/95a6345f805143f7a7521cae86bd5c4b/',
#      'format': 'mp4',
#      'ratio': '16x9',
#      'bitrate': '1200k'},
#     {'profile': 'iphone-16x9',
#      'url': 'http://urs.pbs.org/redirect/19ff5dff95de4109ac152e8668b1a494/'},
#     {'profile': 'hls-800k-16x9',
#      'url': 'http://urs.pbs.org/redirect/1f0b84badd824398a55c08e6f7a5df21/',
#      'format': 'hls',
#      'ratio': '16x9',
#      'bitrate': '800k'},
#     {'profile': 'hls-400-2500k-16x9',
#      'url': 'http://urs.pbs.org/redirect/729f768e04b94619b9d84ba63a2145c9/',
#      'format': 'hls',
#      'ratio': '16x9',
#      'bitrate': '2500k'},
#     {'profile': 'hls-2500k-16x9',
#      'url': 'http://urs.pbs.org/redirect/5e5c4c4af4844397b7f838fa53b38529/',
#      'format': 'hls',
#      'ratio': '16x9',
#      'bitrate': '2500k'}],
#    'series_title': 'WordGirl',
#    'series_slug': 'wordgirl',
#    'series_nola': 'WORG',
#    'supports': {'hls': True, 'mp4': True},
#    'guid': '404112b3-0c95-48a2-b608-98e97f8f9217',
#    'description': 'WordGirl and TJ becoming glued together. / Becky has to take home the class pet',
#    'keywords': ['wordgirl',
#     'word girl',
#     'literacy',
#     'learning',
#     'words',
#     'word',
#     'educate',
#     'define',
#     'becky',
#     'botsford',
#     'education',
#     'superpowers',
#     'superhero'],
#    'media_id': 2365490963,
#    'nola_episode': 'WORG808',
#    'expirationdate': '2018-08-31T04:00:59Z',
#    'availabledate': '2018-08-03T04:00:00Z'},
#   {'type': 'Episode',
#    'links': {'self': 'https://media.services.pbs.org/api/v1/assets/e0929e73-b939-44f9-93a5-2bbfa5ff2d3e/'},
#    'id': 'e0929e73-b939-44f9-93a5-2bbfa5ff2d3e',
#    'slug': 'wild-kratts-back-creature-time-part-2',
#    'title': 'Back in Creature Time Part 2',
#    'title_sortable': 'Back in Creature Time Part 2',
#    'description_short': 'The Wild Kratts go back in time to visit the extinct Tasmanian tiger.',
#    'description_long': 'The Wild Kratts travel back in time to visit another extinct animal--the Tasmanian tiger! Their trip doesn’t go as planned, however, and they must save the Tasmanian tigers from Dabio and Donita’s ancestors, while also saving themselves from Zach, who wants to trap them in the past forever!',
#    'object_type': 'full_length',
#    'premiered_on': '2014-07-09',
#    'encored_on': '2018-08-03',
#    'is_excluded_from_dfp': False,
#    'duration': 1586,
#    'content_rating': 'TV-Y',
#    'content_rating_descriptor': [],
#    'legacy_tp_media_id': 2365277116,
#    'can_embed_player': False,
#    'tags': ['wild kratts',
#     'kratt brothers',
#     'kratts',
#     'kratt',
#     'back in creature time',
#     'back in creature time part 2',
#     'tasmanian tiger',
#     'tasmanian tigers',
#     'extinct',
#     'time trampoline',
#     'dabio',
#     'donita',
#     'zach varmitech',
#     'full episode',
#     'full episodes',
#     'episode',
#     'episodes'],
#    'language': 'en',
#    'funder_message': '',
#    'images': {'kids-mezzannine-4x3': {'profile': 'asset-kids-mezzanine-4x3',
#      'updated_at': '2017-04-25T07:30:18.227356Z',
#      'url': 'https://image.pbs.org/video-assets/pbs-kids/wild-kratts/134306/images/kids-mezzannine-4x3_728.jpg'},
#     'kids-mezzannine-16x9': {'profile': 'asset-kids-mezzanine1-16x9',
#      'updated_at': '2017-04-25T07:30:18.227356Z',
#      'url': 'https://image.pbs.org/video-assets/pbs-kids/wild-kratts/134306/images/kids-mezzannine-16x9_327.jpg'},
#     'thumbnailkidsgodefault': {'profile': 'thumbnailkidsgodefault',
#      'url': 'https://image.pbs.org/video-assets/pbs-kids/wild-kratts/134306/images/kids-mezzannine-4x3_728.jpg.resize.69x53.png'},
#     'googlethumbnail': {'profile': 'googlethumbnail',
#      'url': 'https://image.pbs.org/video-assets/pbs-kids/wild-kratts/134306/images/kids-mezzannine-4x3_728.jpg.resize.160x120.png'}},
#    'updated_at': '2018-08-02T21:54:33.248220Z',
#    'countries': [{'name': 'United States',
#      'code': 'US',
#      'updated_at': '2017-04-04T09:00:32.190936Z',
#      'id': '6a9df090-8ede-44c0-8781-5ddbb942966b'},
#     {'name': 'Northern Mariana Islands',
#      'code': 'MP',
#      'updated_at': '2017-04-04T09:00:32.372517Z',
#      'id': '9a9c8e4e-a700-4713-85f4-b3ee31a27879'},
#     {'name': 'Puerto Rico',
#      'code': 'PR',
#      'updated_at': '2017-04-04T09:00:32.377009Z',
#      'id': 'f3c41bf8-f17c-4b55-a540-0e74c80c2cce'},
#     {'name': 'American Samoa',
#      'code': 'AS',
#      'updated_at': '2017-04-04T09:00:32.381542Z',
#      'id': 'c54cfde7-42cb-49df-bb72-d355332d50c9'},
#     {'name': 'Guam',
#      'code': 'GU',
#      'updated_at': '2017-04-04T09:00:32.386117Z',
#      'id': '4f9b354c-7ada-4d83-9085-fcb6c887a5b5'},
#     {'name': 'U.S. Virgin Islands',
#      'code': 'VI',
#      'updated_at': '2017-04-04T09:00:32.390727Z',
#      'id': 'eefe903e-3af4-4b31-a796-3a4b6dd19214'},
#     {'name': 'U.S. Minor Outlying Islands',
#      'code': 'UM',
#      'updated_at': '2017-04-04T09:00:32.395225Z',
#      'id': 'cf58f575-b194-48e3-8700-1086909ed0e1'}],
#    'geo_profile': {'name': 'US & Territories',
#     'updated_at': '2017-04-04T09:00:32.641361Z',
#     'id': 'c94e2e6d-0052-493a-a67d-266d51cc6445'},
#    'topics': [],
#    'platforms': [{'slug': 'allplatforms',
#      'name': 'All Platforms',
#      'updated_at': '2017-04-03T15:57:09.459445Z',
#      'id': 'e5a289b8-01b3-41ce-92c1-3eb5a4e14bc0'}],
#    'player_code': "<iframe  id='partnerPlayer' frameborder='0' marginwidth='0' marginheight='0' scrolling='no' width='100%' height='100%' src='//player.pbs.org/partnerplayer/T3IPY3VTLWz6NvqFVtcaXw==/?topbar=false&end=0&endscreen=true&start=0&autoplay=false' allowfullscreen></iframe>",
#    'availabilities': {'all_members': {'end': '2018-08-31T04:00:59Z',
#      'start': '2018-08-03T04:00:00Z',
#      'updated_at': '2018-08-02T21:54:24.983541Z'},
#     'station_members': {'end': '2018-08-31T04:00:59Z',
#      'start': '2018-08-03T04:00:00Z',
#      'updated_at': '2018-08-02T21:54:25.036790Z'},
#     'public': {'end': '2018-08-31T04:00:59Z',
#      'start': '2018-08-03T04:00:00Z',
#      'updated_at': '2018-08-02T21:54:24.926480Z'}},
#    'related_links': [],
#    'related_promos': [],
#    'parent_tree': {'type': 'episode',
#     'links': {'self': 'https://media.services.pbs.org/api/v1/episodes/c0091d95-2d71-4e13-ac07-f362bd87df1c/'},
#     'attributes': {'slug': 'wild-kratts-back-creature-time-part-2',
#      'title': 'Back in Creature Time Part 2',
#      'season': {'type': 'season',
#       'links': {'self': 'https://media.services.pbs.org/api/v1/seasons/76aa6df0-cc0d-4f25-a6d6-a56ffed6a4fc/'},
#       'attributes': {'show': {'type': 'show',
#         'links': {'self': 'https://media.services.pbs.org/api/v1/shows/84014647-a8e8-4802-876a-2e2e8fe3ceeb/'},
#         'attributes': {'slug': 'wild-kratts',
#          'seasons_count': 5,
#          'display_episode_number': True,
#          'franchise': None,
#          'tracking_ga_event': 'UA-18413296-2',
#          'title': 'Wild Kratts',
#          'tracking_ga_page': ''},
#         'id': '84014647-a8e8-4802-876a-2e2e8fe3ceeb'},
#        'title': '',
#        'ordinal': 3},
#       'id': '76aa6df0-cc0d-4f25-a6d6-a56ffed6a4fc'},
#      'ordinal': 26},
#     'id': 'c0091d95-2d71-4e13-ac07-f362bd87df1c'},
#    'has_captions': True,
#    'episode': {'type': 'episode',
#     'links': {'self': 'https://media.services.pbs.org/api/v1/episodes/c0091d95-2d71-4e13-ac07-f362bd87df1c/'},
#     'attributes': {'slug': 'wild-kratts-back-creature-time-part-2',
#      'ordinal': 26,
#      'segment': '',
#      'title': 'Back in Creature Time Part 2',
#      'title_sortable': 'Back in Creature Time Part 2',
#      'updated_at': '2018-08-02T21:54:12.599068Z'},
#     'id': 'c0091d95-2d71-4e13-ac07-f362bd87df1c'},
#    'season': None,
#    'show': None,
#    'franchise': None,
#    'chapters': [],
#    'captions': {'caption-sami': {'url': 'https://kids.video.cdn.pbs.org/captions/wild-kratts/e0929e73-b939-44f9-93a5-2bbfa5ff2d3e/captions/0a2vY5_caption.sami',
#      'profile': 'Caption-SAMI'},
#     'dfxp': {'url': 'https://kids.video.cdn.pbs.org/captions/wild-kratts/e0929e73-b939-44f9-93a5-2bbfa5ff2d3e/captions/1ATzTj_caption.dfxp',
#      'profile': 'DFXP'},
#     'srt': {'url': 'https://kids.video.cdn.pbs.org/captions/wild-kratts/e0929e73-b939-44f9-93a5-2bbfa5ff2d3e/captions/m512sP_caption.srt',
#      'profile': 'SRT'},
#     'webvtt': {'url': 'https://kids.video.cdn.pbs.org/captions/wild-kratts/e0929e73-b939-44f9-93a5-2bbfa5ff2d3e/captions/ZRL3yM_caption.vtt',
#      'profile': 'WebVTT'}},
#    'videos': [{'url': 'https://urs.pbs.org/redirect/d5ecdc16e453450fb7ecf80e1bc2953a/',
#      'profile': 'mp4-16x9-baseline',
#      'format': 'mp4',
#      'ratio': '16x9',
#      'bitrate': None},
#     {'url': 'https://urs.pbs.org/redirect/71c4c9e591454e26a29d225df8f609f6/',
#      'profile': 'mp4-16x9-720p',
#      'format': 'mp4',
#      'ratio': '16x9',
#      'bitrate': '720p'},
#     {'url': 'https://urs.pbs.org/redirect/ad7d6706f3fc45629d497af119351407/',
#      'profile': 'hls-16x9-720p',
#      'format': 'hls',
#      'ratio': '16x9',
#      'bitrate': '720p'},
#     {'url': 'https://urs.pbs.org/redirect/61abf6e129c347c694986bcb41da1f9a/',
#      'profile': 'hls-16x9-1080p',
#      'format': 'hls',
#      'ratio': '16x9',
#      'bitrate': '1080p'}],
#    'series_title': 'Wild Kratts',
#    'series_slug': 'wild-kratts',
#    'series_nola': 'WILK',
#    'supports': {'hls': True, 'mp4': True},
#    'guid': 'e0929e73-b939-44f9-93a5-2bbfa5ff2d3e',
#    'description': 'The Wild Kratts travel back in time to visit another extinct animal--the Tasmanian tiger! Their trip doesn’t go as planned, however, and they must save the Tasmanian tigers from Dabio and Donita’s ancestors, while also saving themselves from Zach, who wants to trap them in the past forever!',
#    'keywords': ['wild kratts',
#     'kratt brothers',
#     'kratts',
#     'kratt',
#     'back in creature time',
#     'back in creature time part 2',
#     'tasmanian tiger',
#     'tasmanian tigers',
#     'extinct',
#     'time trampoline',
#     'dabio',
#     'donita',
#     'zach varmitech',
#     'full episode',
#     'full episodes',
#     'episode',
#     'episodes'],
#    'media_id': 2365277116,
#    'nola_episode': 'WILK326',
#    'expirationdate': '2018-08-31T04:00:59Z',
#    'availabledate': '2018-08-03T04:00:00Z'},
#   {'type': 'Episode',
#    'links': {'self': 'https://media.services.pbs.org/api/v1/assets/fc90ba77-e99e-4ff5-9cfc-cbeb765b8e42/'},
#    'id': 'fc90ba77-e99e-4ff5-9cfc-cbeb765b8e42',
#    'slug': 'sid-the-science-kid-reused-robot',
#    'title': 'Reused Robot',
#    'title_sortable': 'Reused Robot',
#    'description_short': 'Sid and his friends explore the idea that everything we throw away goes somewhere.',
#    'description_long': 'Sid\'s toy robot is broken, so he wants to throw it "away." Sid\'s Mom tells him there is no such thing as "away," and when we put something in the trash, we are actually creating waste.  Sid and his friends explore the idea that everything we throw away goes somewhere.  This leads to an investigation of how to recycle and reuse items so that we make less trash.',
#    'object_type': 'full_length',
#    'premiered_on': '2011-04-20',
#    'encored_on': '2018-08-03',
#    'is_excluded_from_dfp': False,
#    'duration': 1557,
#    'content_rating': 'TV-Y',
#    'content_rating_descriptor': [],
#    'legacy_tp_media_id': 1884216858,
#    'can_embed_player': False,
#    'tags': ['sid the science kid',
#     'full episode',
#     'full episodes',
#     'recycling',
#     'recyle',
#     'robot',
#     'reuse',
#     'waste',
#     'trash',
#     'toys'],
#    'language': 'en',
#    'funder_message': '',
#    'images': {'kids-mezzannine-4x3': {'profile': 'asset-kids-mezzanine-4x3',
#      'updated_at': '2017-04-25T07:30:18.227356Z',
#      'url': 'https://image.pbs.org/video-assets/pbs-kids/sid-science-kid/62818/images/Kids-Mezzannine-4x3_386.jpg'},
#     'kids-mezzannine-16x9': {'profile': 'asset-kids-mezzanine1-16x9',
#      'updated_at': '2017-04-25T07:30:18.227356Z',
#      'url': 'https://image.pbs.org/video-assets/pbs-kids/sid-science-kid/62818/images/Kids-Mezzannine-16x9_107.jpg'},
#     'thumbnailkidsgodefault': {'profile': 'thumbnailkidsgodefault',
#      'url': 'https://image.pbs.org/video-assets/pbs-kids/sid-science-kid/62818/images/Kids-Mezzannine-4x3_386.jpg.resize.69x53.png'},
#     'googlethumbnail': {'profile': 'googlethumbnail',
#      'url': 'https://image.pbs.org/video-assets/pbs-kids/sid-science-kid/62818/images/Kids-Mezzannine-4x3_386.jpg.resize.160x120.png'}},
#    'updated_at': '2018-08-02T21:53:22.299719Z',
#    'countries': [{'name': 'United States',
#      'code': 'US',
#      'updated_at': '2017-04-04T09:00:32.190936Z',
#      'id': '6a9df090-8ede-44c0-8781-5ddbb942966b'},
#     {'name': 'Northern Mariana Islands',
#      'code': 'MP',
#      'updated_at': '2017-04-04T09:00:32.372517Z',
#      'id': '9a9c8e4e-a700-4713-85f4-b3ee31a27879'},
#     {'name': 'Puerto Rico',
#      'code': 'PR',
#      'updated_at': '2017-04-04T09:00:32.377009Z',
#      'id': 'f3c41bf8-f17c-4b55-a540-0e74c80c2cce'},
#     {'name': 'American Samoa',
#      'code': 'AS',
#      'updated_at': '2017-04-04T09:00:32.381542Z',
#      'id': 'c54cfde7-42cb-49df-bb72-d355332d50c9'},
#     {'name': 'Guam',
#      'code': 'GU',
#      'updated_at': '2017-04-04T09:00:32.386117Z',
#      'id': '4f9b354c-7ada-4d83-9085-fcb6c887a5b5'},
#     {'name': 'U.S. Virgin Islands',
#      'code': 'VI',
#      'updated_at': '2017-04-04T09:00:32.390727Z',
#      'id': 'eefe903e-3af4-4b31-a796-3a4b6dd19214'},
#     {'name': 'U.S. Minor Outlying Islands',
#      'code': 'UM',
#      'updated_at': '2017-04-04T09:00:32.395225Z',
#      'id': 'cf58f575-b194-48e3-8700-1086909ed0e1'}],
#    'geo_profile': {'name': 'US & Territories',
#     'updated_at': '2017-04-04T09:00:32.641361Z',
#     'id': 'c94e2e6d-0052-493a-a67d-266d51cc6445'},
#    'topics': [{'name': 'Science',
#      'updated_at': '2017-04-04T09:00:06.181288Z',
#      'parent': None,
#      'id': '8b4c77ba-7e45-4207-9566-f916e108a25f'}],
#    'platforms': [{'slug': 'allplatforms',
#      'name': 'All Platforms',
#      'updated_at': '2017-04-03T15:57:09.459445Z',
#      'id': 'e5a289b8-01b3-41ce-92c1-3eb5a4e14bc0'}],
#    'player_code': "<iframe  id='partnerPlayer' frameborder='0' marginwidth='0' marginheight='0' scrolling='no' width='100%' height='100%' src='//player.pbs.org/partnerplayer/hL-1QT2vvQ48FZ0V2W6A-w==/?topbar=false&end=0&endscreen=true&start=0&autoplay=false' allowfullscreen></iframe>",
#    'availabilities': {'all_members': {'end': '2018-08-31T04:00:59Z',
#      'start': '2018-08-03T04:00:00Z',
#      'updated_at': '2018-08-02T21:53:13.939456Z'},
#     'station_members': {'end': '2018-08-31T04:00:59Z',
#      'start': '2018-08-03T04:00:00Z',
#      'updated_at': '2018-08-02T21:53:14.011936Z'},
#     'public': {'end': '2018-08-31T04:00:59Z',
#      'start': '2018-08-03T04:00:00Z',
#      'updated_at': '2018-08-02T21:53:13.857944Z'}},
#    'related_links': [],
#    'related_promos': [],
#    'parent_tree': {'type': 'episode',
#     'links': {'self': 'https://media.services.pbs.org/api/v1/episodes/204ce297-4821-49e9-a4f6-4367b08484e2/'},
#     'attributes': {'slug': 'sid-the-science-kid-reused-robot',
#      'title': 'Reused Robot',
#      'season': {'type': 'season',
#       'links': {'self': 'https://media.services.pbs.org/api/v1/seasons/5a933643-113d-451b-8d61-cf9ee01f2e61/'},
#       'attributes': {'show': {'type': 'show',
#         'links': {'self': 'https://media.services.pbs.org/api/v1/shows/9450761d-b0ca-4bcd-8bcb-8fd6cdb10719/'},
#         'attributes': {'slug': 'sid-science-kid',
#          'seasons_count': 2,
#          'display_episode_number': True,
#          'franchise': None,
#          'tracking_ga_event': 'UA-5035505-2',
#          'title': 'Sid the Science Kid',
#          'tracking_ga_page': ''},
#         'id': '9450761d-b0ca-4bcd-8bcb-8fd6cdb10719'},
#        'title': '',
#        'ordinal': 2},
#       'id': '5a933643-113d-451b-8d61-cf9ee01f2e61'},
#      'ordinal': 8},
#     'id': '204ce297-4821-49e9-a4f6-4367b08484e2'},
#    'has_captions': True,
#    'episode': {'type': 'episode',
#     'links': {'self': 'https://media.services.pbs.org/api/v1/episodes/204ce297-4821-49e9-a4f6-4367b08484e2/'},
#     'attributes': {'slug': 'sid-the-science-kid-reused-robot',
#      'ordinal': 8,
#      'segment': '',
#      'title': 'Reused Robot',
#      'title_sortable': 'Reused Robot',
#      'updated_at': '2018-08-02T21:53:02.352753Z'},
#     'id': '204ce297-4821-49e9-a4f6-4367b08484e2'},
#    'season': None,
#    'show': None,
#    'franchise': None,
#    'chapters': [],
#    'captions': {'caption-sami': {'url': 'http://kids.video.cdn.pbs.org/captions/sid-science-kid/fc90ba77-e99e-4ff5-9cfc-cbeb765b8e42/captions/184881_Encoded.sami',
#      'profile': 'Caption-SAMI'},
#     'dfxp': {'url': 'http://kids.video.cdn.pbs.org/captions/sid-science-kid/fc90ba77-e99e-4ff5-9cfc-cbeb765b8e42/captions/184882_Encoded.dfxp',
#      'profile': 'DFXP'},
#     'srt': {'url': 'http://kids.video.cdn.pbs.org/captions/sid-science-kid/fc90ba77-e99e-4ff5-9cfc-cbeb765b8e42/captions/184883_Encoded.srt',
#      'profile': 'SRT'},
# ...
#      'updated_at': '2018-08-02T18:05:34.243787Z',
#      'url': 'http://image.pbs.org/video-assets/LGs5QFx-asset-kids-mezzanine-4x3-LfNHQUQ.jpg'},
#     'kids-mezzannine-16x9': {'profile': 'asset-kids-mezzanine1-16x9',
#      'updated_at': '2018-08-02T18:05:42.747348Z',
#      'url': 'http://image.pbs.org/video-assets/1VreyNy-asset-kids-mezzanine1-16x9-cBy7Zrc.jpg'},
#     'thumbnailkidsgodefault': {'profile': 'thumbnailkidsgodefault',
#      'url': 'http://image.pbs.org/video-assets/LGs5QFx-asset-kids-mezzanine-4x3-LfNHQUQ.jpg.resize.69x53.png'},
#     'googlethumbnail': {'profile': 'googlethumbnail',
#      'url': 'http://image.pbs.org/video-assets/LGs5QFx-asset-kids-mezzanine-4x3-LfNHQUQ.jpg.resize.160x120.png'}},
#    'updated_at': '2018-08-02T18:30:29.741626Z',
#    'countries': [{'name': 'United States',
#      'code': 'US',
#      'updated_at': '2017-04-04T09:00:32.190936Z',
#      'id': '6a9df090-8ede-44c0-8781-5ddbb942966b'},
#     {'name': 'Northern Mariana Islands',
#      'code': 'MP',
#      'updated_at': '2017-04-04T09:00:32.372517Z',
#      'id': '9a9c8e4e-a700-4713-85f4-b3ee31a27879'},
#     {'name': 'Puerto Rico',
#      'code': 'PR',
#      'updated_at': '2017-04-04T09:00:32.377009Z',
#      'id': 'f3c41bf8-f17c-4b55-a540-0e74c80c2cce'},
#     {'name': 'American Samoa',
#      'code': 'AS',
#      'updated_at': '2017-04-04T09:00:32.381542Z',
#      'id': 'c54cfde7-42cb-49df-bb72-d355332d50c9'},
#     {'name': 'Guam',
#      'code': 'GU',
#      'updated_at': '2017-04-04T09:00:32.386117Z',
#      'id': '4f9b354c-7ada-4d83-9085-fcb6c887a5b5'},
#     {'name': 'U.S. Virgin Islands',
#      'code': 'VI',
#      'updated_at': '2017-04-04T09:00:32.390727Z',
#      'id': 'eefe903e-3af4-4b31-a796-3a4b6dd19214'},
#     {'name': 'U.S. Minor Outlying Islands',
#      'code': 'UM',
#      'updated_at': '2017-04-04T09:00:32.395225Z',
#      'id': 'cf58f575-b194-48e3-8700-1086909ed0e1'}],
#    'geo_profile': {'name': 'US & Territories',
#     'updated_at': '2017-04-04T09:00:32.641361Z',
#     'id': 'c94e2e6d-0052-493a-a67d-266d51cc6445'},
#    'topics': [{'name': 'Science',
#      'updated_at': '2017-04-04T09:00:06.181288Z',
#      'parent': None,
#      'id': '8b4c77ba-7e45-4207-9566-f916e108a25f'},
#     {'name': 'Transportation',
#      'updated_at': '2017-04-04T09:00:07.103050Z',
#      'parent': {'name': 'Science',
#       'updated_at': '2017-04-04T09:00:06.181288Z',
#       'id': '8b4c77ba-7e45-4207-9566-f916e108a25f'},
#      'id': '635a8029-64f3-409d-ad7d-3d2f537e9796'},
#     {'name': 'Dinosaurs',
#      'updated_at': '2017-04-04T09:00:07.184516Z',
#      'parent': {'name': 'Science',
#       'updated_at': '2017-04-04T09:00:06.181288Z',
#       'id': '8b4c77ba-7e45-4207-9566-f916e108a25f'},
#      'id': '9b16fa1e-9b33-4590-8156-463d743bc90d'}],
#    'platforms': [{'slug': 'allplatforms',
#      'name': 'All Platforms',
#      'updated_at': '2017-04-03T15:57:09.459445Z',
#      'id': 'e5a289b8-01b3-41ce-92c1-3eb5a4e14bc0'}],
#    'player_code': "<iframe  id='partnerPlayer' frameborder='0' marginwidth='0' marginheight='0' scrolling='no' width='100%' height='100%' src='//player.pbs.org/partnerplayer/SOcVLiMWC2BXCnbT9LdKiA==/?topbar=false&end=0&endscreen=true&start=0&autoplay=false' allowfullscreen></iframe>",
#    'availabilities': {'all_members': {'end': None,
#      'start': '2018-08-03T04:00:00Z',
#      'updated_at': '2018-08-02T18:04:38.856900Z'},
#     'station_members': {'end': None,
#      'start': '2018-08-03T04:00:00Z',
#      'updated_at': '2018-08-02T18:04:38.872873Z'},
#     'public': {'end': None,
#      'start': '2018-08-03T04:00:00Z',
#      'updated_at': '2018-08-02T18:04:38.838997Z'}},
#    'related_links': [],
#    'related_promos': [],
#    'parent_tree': {'type': 'episode',
#     'links': {'self': 'https://media.services.pbs.org/api/v1/episodes/182fbff3-3bb4-422a-8b03-c60851019a1e/'},
#     'attributes': {'slug': 'laura-giganotosaurusdinosaur-poop-gq6uuo',
#      'title': 'Laura the Giganotosaurus/Dinosaur Poop!',
#      'season': {'type': 'season',
#       'links': {'self': 'https://media.services.pbs.org/api/v1/seasons/813757aa-e655-4775-af71-33780b401a5b/'},
#       'attributes': {'show': {'type': 'show',
#         'links': {'self': 'https://media.services.pbs.org/api/v1/shows/2a95eca4-31e8-4793-821e-0d4bfbf21a2a/'},
#         'attributes': {'slug': 'dinosaur-train',
#          'seasons_count': 4,
#          'display_episode_number': True,
#          'franchise': None,
#          'tracking_ga_event': 'UA-10166683-2',
#          'title': 'Dinosaur Train',
#          'tracking_ga_page': ''},
#         'id': '2a95eca4-31e8-4793-821e-0d4bfbf21a2a'},
#        'title': '',
#        'ordinal': 1},
#       'id': '813757aa-e655-4775-af71-33780b401a5b'},
#      'ordinal': 10},
#     'id': '182fbff3-3bb4-422a-8b03-c60851019a1e'},
#    'has_captions': True,
#    'episode': {'type': 'episode',
#     'links': {'self': 'https://media.services.pbs.org/api/v1/episodes/182fbff3-3bb4-422a-8b03-c60851019a1e/'},
#     'attributes': {'slug': 'laura-giganotosaurusdinosaur-poop-gq6uuo',
#      'ordinal': 10,
#      'segment': '',
#      'title': 'Laura the Giganotosaurus/Dinosaur Poop!',
#      'title_sortable': 'Laura the Giganotosaurus/Dinosaur Poop!',
#      'updated_at': '2018-08-02T17:39:40.406906Z'},
#     'id': '182fbff3-3bb4-422a-8b03-c60851019a1e'},
#    'season': None,
#    'show': None,
#    'franchise': None,
#    'chapters': [],
#    'captions': {'webvtt': {'url': 'https://kids.video.cdn.pbs.org/captions/dinosaur-train/9e2012cd-c7f7-41d1-84c6-1ed37b360f63/captions/hbYRF4_caption.vtt',
#      'profile': 'WebVTT'},
#     'srt': {'url': 'https://kids.video.cdn.pbs.org/captions/dinosaur-train/9e2012cd-c7f7-41d1-84c6-1ed37b360f63/captions/N3CVp6_caption.srt',
#      'profile': 'SRT'},
#     'dfxp': {'url': 'https://kids.video.cdn.pbs.org/captions/dinosaur-train/9e2012cd-c7f7-41d1-84c6-1ed37b360f63/captions/lLjNZz_caption.dfxp',
#      'profile': 'DFXP'},
#     'caption-sami': {'url': 'https://kids.video.cdn.pbs.org/captions/dinosaur-train/9e2012cd-c7f7-41d1-84c6-1ed37b360f63/captions/4RgzfY_caption.sami',
#      'profile': 'Caption-SAMI'}},
#    'videos': [{'url': 'https://urs.pbs.org/redirect/0661b9a0081640a8bb8a23565100892b/',
#      'profile': 'hls-16x9-1080p',
#      'format': 'hls',
#      'ratio': '16x9',
#      'bitrate': '1080p'},
#     {'url': 'https://urs.pbs.org/redirect/ca16aa216e9d4e4189be9ba2fb02b48f/',
#      'profile': 'hls-16x9-720p',
#      'format': 'hls',
#      'ratio': '16x9',
#      'bitrate': '720p'},
#     {'url': 'https://urs.pbs.org/redirect/4a1696f2c9624c54a55e7f49f9552f10/',
#      'profile': 'mp4-16x9-baseline',
#      'format': 'mp4',
#      'ratio': '16x9',
#      'bitrate': None},
#     {'url': 'https://urs.pbs.org/redirect/5e5cd603dc384095aba40564f2391920/',
#      'profile': 'mp4-16x9-720p',
#      'format': 'mp4',
#      'ratio': '16x9',
#      'bitrate': '720p'}],
#    'series_title': 'Dinosaur Train',
#    'series_slug': 'dinosaur-train',
#    'series_nola': 'DINS',
#    'supports': {'hls': True, 'mp4': True},
#    'guid': '9e2012cd-c7f7-41d1-84c6-1ed37b360f63',
#    'description': 'Buddy spends time with Laura Giganotosaurus, an avid bird watcher./Buddy and Tiny learn that all creatures poop, even really big dinosaurs.',
#    'keywords': ['dinosaur',
#     'poop',
#     'laura',
#     'giganotosaurus',
#     'bird',
#     'full episode',
#     'full episodes'],
#    'media_id': 3015012122,
#    'nola_episode': 'DINS110',
#    'expirationdate': None,
#    'availabledate': '2018-08-03T04:00:00Z'},
#   {'type': 'Episode',
#    'links': {'self': 'https://media.services.pbs.org/api/v1/assets/c60f57ad-1f97-45a6-8773-21adb7adc814/'},
#    'id': 'c60f57ad-1f97-45a6-8773-21adb7adc814',
#    'slug': 'the-wheel-dealthe-buster-report-k1npfz',
#    'title': 'The Wheel Deal/The Buster Report',
#    'title_sortable': 'Wheel Deal/The Buster Report',
#    'description_short': 'Brain needs to spend some time using a wheelchair/The kids write about someone they admire',
#    'description_long': 'After an injury, Brain needs to spend some time in a wheelchair. / The kids have to write a report about someone they admire.',
#    'object_type': 'full_length',
#    'premiered_on': '2011-04-28',
#    'encored_on': '2018-08-03',
#    'is_excluded_from_dfp': False,
#    'duration': 1465,
#    'content_rating': 'TV-Y',
#    'content_rating_descriptor': [],
#    'legacy_tp_media_id': 3015000626,
#    'can_embed_player': False,
#    'tags': ['brain',
#     'wheelchair',
#     'arthur',
#     'buster',
#     'report',
#     'admire',
#     'write',
#     'homework',
#     'assignment',
#     'full episode',
#     'full episodes'],
#    'language': 'en',
#    'funder_message': '',
#    'images': {'kids-mezzannine-4x3': {'profile': 'asset-kids-mezzanine-4x3',
#      'updated_at': '2018-08-02T17:28:08.721060Z',
#      'url': 'http://image.pbs.org/video-assets/ZfbQQsW-asset-kids-mezzanine-4x3-7ooEjTF.jpg'},
#     'kids-mezzannine-16x9': {'profile': 'asset-kids-mezzanine1-16x9',
#      'updated_at': '2018-08-02T17:32:54.113038Z',
#      'url': 'http://image.pbs.org/video-assets/rzJxbLH-asset-kids-mezzanine1-16x9-PCy14F9.jpg'},
#     'thumbnailkidsgodefault': {'profile': 'thumbnailkidsgodefault',
#      'url': 'http://image.pbs.org/video-assets/ZfbQQsW-asset-kids-mezzanine-4x3-7ooEjTF.jpg.resize.69x53.png'},
#     'googlethumbnail': {'profile': 'googlethumbnail',
#      'url': 'http://image.pbs.org/video-assets/ZfbQQsW-asset-kids-mezzanine-4x3-7ooEjTF.jpg.resize.160x120.png'}},
#    'updated_at': '2018-08-02T17:53:31.980283Z',
#    'countries': [{'name': 'United States',
#      'code': 'US',
#      'updated_at': '2017-04-04T09:00:32.190936Z',
#      'id': '6a9df090-8ede-44c0-8781-5ddbb942966b'},
#     {'name': 'Northern Mariana Islands',
#      'code': 'MP',
#      'updated_at': '2017-04-04T09:00:32.372517Z',
#      'id': '9a9c8e4e-a700-4713-85f4-b3ee31a27879'},
#     {'name': 'Puerto Rico',
#      'code': 'PR',
#      'updated_at': '2017-04-04T09:00:32.377009Z',
#      'id': 'f3c41bf8-f17c-4b55-a540-0e74c80c2cce'},
#     {'name': 'American Samoa',
#      'code': 'AS',
#      'updated_at': '2017-04-04T09:00:32.381542Z',
#      'id': 'c54cfde7-42cb-49df-bb72-d355332d50c9'},
#     {'name': 'Guam',
#      'code': 'GU',
#      'updated_at': '2017-04-04T09:00:32.386117Z',
#      'id': '4f9b354c-7ada-4d83-9085-fcb6c887a5b5'},
#     {'name': 'U.S. Virgin Islands',
#      'code': 'VI',
#      'updated_at': '2017-04-04T09:00:32.390727Z',
#      'id': 'eefe903e-3af4-4b31-a796-3a4b6dd19214'},
#     {'name': 'U.S. Minor Outlying Islands',
#      'code': 'UM',
#      'updated_at': '2017-04-04T09:00:32.395225Z',
#      'id': 'cf58f575-b194-48e3-8700-1086909ed0e1'}],
#    'geo_profile': {'name': 'US & Territories',
#     'updated_at': '2017-04-04T09:00:32.641361Z',
#     'id': 'c94e2e6d-0052-493a-a67d-266d51cc6445'},
#    'topics': [{'name': 'Health',
#      'updated_at': '2017-04-04T09:00:06.176249Z',
#      'parent': None,
#      'id': '9cb4797a-9fe0-4347-a2ab-8ab0b27cae39'},
#     {'name': 'Language & Literacy',
#      'updated_at': '2017-04-04T09:00:06.191403Z',
#      'parent': None,
#      'id': '5a28478e-a056-4e4d-9585-e32e7abf62c8'},
#     {'name': 'Human Body',
#      'updated_at': '2017-04-04T09:00:07.040727Z',
#      'parent': {'name': 'Health',
#       'updated_at': '2017-04-04T09:00:06.176249Z',
#       'id': '9cb4797a-9fe0-4347-a2ab-8ab0b27cae39'},
#      'id': 'eddd48b9-160f-4c43-b406-91f4ff48a09d'},
#     {'name': 'Storytelling',
#      'updated_at': '2017-04-04T09:00:07.267839Z',
#      'parent': {'name': 'Language & Literacy',
#       'updated_at': '2017-04-04T09:00:06.191403Z',
#       'id': '5a28478e-a056-4e4d-9585-e32e7abf62c8'},
#      'id': '850a6923-e75d-46af-b7d6-cafce0332919'}],
#    'platforms': [{'slug': 'allplatforms',
#      'name': 'All Platforms',
#      'updated_at': '2017-04-03T15:57:09.459445Z',
#      'id': 'e5a289b8-01b3-41ce-92c1-3eb5a4e14bc0'}],
#    'player_code': "<iframe  id='partnerPlayer' frameborder='0' marginwidth='0' marginheight='0' scrolling='no' width='100%' height='100%' src='//player.pbs.org/partnerplayer/zrh-VGpLeGJ1n6epsty8fA==/?topbar=false&end=0&endscreen=true&start=0&autoplay=false' allowfullscreen></iframe>",
#    'availabilities': {'all_members': {'end': None,
#      'start': '2018-08-03T04:00:00Z',
#      'updated_at': '2018-08-02T16:53:47.500243Z'},
#     'station_members': {'end': None,
#      'start': '2018-08-03T04:00:00Z',
#      'updated_at': '2018-08-02T16:53:47.510984Z'},
#     'public': {'end': None,
#      'start': '2018-08-03T04:00:00Z',
#      'updated_at': '2018-08-02T16:53:47.487493Z'}},
#    'related_links': [],
#    'related_promos': [],
#    'parent_tree': {'type': 'episode',
#     'links': {'self': 'https://media.services.pbs.org/api/v1/episodes/5e8a8375-171c-43c1-bbce-c50399657500/'},
#     'attributes': {'slug': 'wheel-deal-buster-report-1picbg',
#      'title': 'The Wheel Deal/The Buster Report',
#      'season': {'type': 'season',
#       'links': {'self': 'https://media.services.pbs.org/api/v1/seasons/ef2fde89-edfd-4381-960a-cbee5a451915/'},
#       'attributes': {'show': {'type': 'show',
#         'links': {'self': 'https://media.services.pbs.org/api/v1/shows/33c4af5a-72bf-4abb-8e2a-ffe83be42c3e/'},
#         'attributes': {'slug': 'arthur',
#          'seasons_count': 21,
#          'display_episode_number': True,
#          'franchise': None,
#          'tracking_ga_event': 'UA-3999950-2',
#          'title': 'Arthur',
#          'tracking_ga_page': ''},
#         'id': '33c4af5a-72bf-4abb-8e2a-ffe83be42c3e'},
#        'title': '',
#        'ordinal': 14},
#       'id': 'ef2fde89-edfd-4381-960a-cbee5a451915'},
#      'ordinal': 1},
#     'id': '5e8a8375-171c-43c1-bbce-c50399657500'},
#    'has_captions': True,
#    'episode': {'type': 'episode',
#     'links': {'self': 'https://media.services.pbs.org/api/v1/episodes/5e8a8375-171c-43c1-bbce-c50399657500/'},
#     'attributes': {'slug': 'wheel-deal-buster-report-1picbg',
#      'ordinal': 1,
#      'segment': '',
#      'title': 'The Wheel Deal/The Buster Report',
#      'title_sortable': 'Wheel Deal/The Buster Report',
#      'updated_at': '2018-08-02T15:51:33.558346Z'},
#     'id': '5e8a8375-171c-43c1-bbce-c50399657500'},
#    'season': None,
#    'show': None,
#    'franchise': None,
#    'chapters': [],
#    'captions': {'webvtt': {'url': 'https://kids.video.cdn.pbs.org/captions/arthur/c60f57ad-1f97-45a6-8773-21adb7adc814/captions/5HzYH6_caption.vtt',
#      'profile': 'WebVTT'},
#     'srt': {'url': 'https://kids.video.cdn.pbs.org/captions/arthur/c60f57ad-1f97-45a6-8773-21adb7adc814/captions/rXY1Sc_caption.srt',
#      'profile': 'SRT'},
#     'dfxp': {'url': 'https://kids.video.cdn.pbs.org/captions/arthur/c60f57ad-1f97-45a6-8773-21adb7adc814/captions/doOFlE_caption.dfxp',
#      'profile': 'DFXP'},
#     'caption-sami': {'url': 'https://kids.video.cdn.pbs.org/captions/arthur/c60f57ad-1f97-45a6-8773-21adb7adc814/captions/81w43E_caption.sami',
#      'profile': 'Caption-SAMI'}},
#    'videos': [{'url': 'https://urs.pbs.org/redirect/424c1b922fb4437488fe904578772313/',
#      'profile': 'hls-16x9-1080p',
#      'format': 'hls',
#      'ratio': '16x9',
#      'bitrate': '1080p'},
#     {'url': 'https://urs.pbs.org/redirect/7a062dc467864d32a56000090921a73c/',
#      'profile': 'hls-16x9-720p',
#      'format': 'hls',
#      'ratio': '16x9',
#      'bitrate': '720p'},
#     {'url': 'https://urs.pbs.org/redirect/3b939d77bbd64ab8aad77371b538a37c/',
#      'profile': 'mp4-16x9-baseline',
#      'format': 'mp4',
#      'ratio': '16x9',
#      'bitrate': None},
#     {'url': 'https://urs.pbs.org/redirect/5c2daac8ef984df59e201fc0c9a8e3fb/',
#      'profile': 'mp4-16x9-720p',
#      'format': 'mp4',
#      'ratio': '16x9',
#      'bitrate': '720p'}],
#    'series_title': 'Arthur',
#    'series_slug': 'arthur',
#    'series_nola': 'ARUR',
#    'supports': {'hls': True, 'mp4': True},
#    'guid': 'c60f57ad-1f97-45a6-8773-21adb7adc814',
#    'description': 'After an injury, Brain needs to spend some time in a wheelchair. / The kids have to write a report about someone they admire.',
#    'keywords': ['brain',
#     'wheelchair',
#     'arthur',
#     'buster',
#     'report',
#     'admire',
#     'write',
#     'homework',
#     'assignment',
#     'full episode',
#     'full episodes'],
#    'media_id': 3015000626,
#    'nola_episode': 'ARUR1401',
#    'expirationdate': None,
#    'availabledate': '2018-08-03T04:00:00Z'}],
#  'matched': 5941,
#  'isLastPage': False,
#  'page': 1,
#  'page_size': 20}

# %%
url = "https://producerplayer.services.pbskids.org/show-list/?shows=curious-george"

# %%
resp = requests.get(
    url=url,
)
assert(resp.status_code==200)

# %%
r = resp.json()

# %%
r.keys()
# Out:
# dict_keys(['items', 'matched', 'isLastPage'])

# %%
len(r["items"])
# Out:
# 25

# %%
r["matched"]
# Out:
# 270

# %%
r["isLastPage"]
# Out:
# False

# %%
for item in r["items"]:
    break

# %%
item
# Out:
# {'type': 'Episode',
#  'links': {'self': 'https://media.services.pbs.org/api/v1/assets/7c54cabe-d81e-43cf-9bce-ce9fd99f2b6e/'},
#  'id': '7c54cabe-d81e-43cf-9bce-ce9fd99f2b6e',
#  'slug': 'curious-george-monkey-down-under',
#  'title': 'Monkey Down Under',
#  'title_sortable': 'Monkey Down Under',
#  'description_short': 'George investigates some mysterious footprints on his Australian outback adventure.',
#  'description_long': 'George and The Man with the Yellow Hat head to the land down under for an Australian adventure. While the Man goes sea cow sightseeing, George stays behind to investigate the creature that left a set of giant footprints in the sand. Could it be a mysterious hopping clown rabbit?',
#  'object_type': 'full_length',
#  'premiered_on': '2012-12-03',
#  'encored_on': '2018-08-03',
#  'is_excluded_from_dfp': False,
#  'duration': 746,
#  'content_rating': 'TV-Y',
#  'content_rating_descriptor': [],
#  'legacy_tp_media_id': 2365465333,
#  'can_embed_player': False,
#  'tags': ['curious george',
#   'george',
#   'monkey down under',
#   'australia',
#   'outback',
#   'australian outback',
#   'kangaroo',
#   'kangaroos',
#   'manatees',
#   'sea cow',
#   'sea cows',
#   'animals',
#   'science',
#   'mammals',
#   'full episode',
#   'full episodes',
#   'episode',
#   'episodes'],
#  'language': 'en',
#  'funder_message': '',
#  'images': {'kids-mezzannine-4x3': {'profile': 'asset-kids-mezzanine-4x3',
#    'updated_at': '2017-04-25T07:30:18.227356Z',
#    'url': 'https://image.pbs.org/video-assets/pbs-kids/curious-george/168976/images/kids-mezzannine-4x3_937.jpg'},
#   'kids-mezzannine-16x9': {'profile': 'asset-kids-mezzanine1-16x9',
#    'updated_at': '2017-04-25T07:30:18.227356Z',
#    'url': 'https://image.pbs.org/video-assets/pbs-kids/curious-george/168976/images/kids-mezzannine-16x9_739.jpg'},
#   'thumbnailkidsgodefault': {'profile': 'thumbnailkidsgodefault',
#    'url': 'https://image.pbs.org/video-assets/pbs-kids/curious-george/168976/images/kids-mezzannine-4x3_937.jpg.resize.69x53.png'},
#   'googlethumbnail': {'profile': 'googlethumbnail',
#    'url': 'https://image.pbs.org/video-assets/pbs-kids/curious-george/168976/images/kids-mezzannine-4x3_937.jpg.resize.160x120.png'}},
#  'updated_at': '2018-07-30T15:47:57.243143Z',
#  'countries': [{'name': 'United States',
#    'code': 'US',
#    'updated_at': '2017-04-04T09:00:32.190936Z',
#    'id': '6a9df090-8ede-44c0-8781-5ddbb942966b'},
#   {'name': 'Northern Mariana Islands',
#    'code': 'MP',
#    'updated_at': '2017-04-04T09:00:32.372517Z',
#    'id': '9a9c8e4e-a700-4713-85f4-b3ee31a27879'},
#   {'name': 'Puerto Rico',
#    'code': 'PR',
#    'updated_at': '2017-04-04T09:00:32.377009Z',
#    'id': 'f3c41bf8-f17c-4b55-a540-0e74c80c2cce'},
#   {'name': 'American Samoa',
#    'code': 'AS',
#    'updated_at': '2017-04-04T09:00:32.381542Z',
#    'id': 'c54cfde7-42cb-49df-bb72-d355332d50c9'},
#   {'name': 'Guam',
#    'code': 'GU',
#    'updated_at': '2017-04-04T09:00:32.386117Z',
#    'id': '4f9b354c-7ada-4d83-9085-fcb6c887a5b5'},
#   {'name': 'U.S. Virgin Islands',
#    'code': 'VI',
#    'updated_at': '2017-04-04T09:00:32.390727Z',
#    'id': 'eefe903e-3af4-4b31-a796-3a4b6dd19214'},
#   {'name': 'U.S. Minor Outlying Islands',
#    'code': 'UM',
#    'updated_at': '2017-04-04T09:00:32.395225Z',
#    'id': 'cf58f575-b194-48e3-8700-1086909ed0e1'}],
#  'geo_profile': {'name': 'US & Territories',
#   'updated_at': '2017-04-04T09:00:32.641361Z',
#   'id': 'c94e2e6d-0052-493a-a67d-266d51cc6445'},
#  'topics': [{'name': 'Science',
#    'updated_at': '2017-04-04T09:00:06.181288Z',
#    'parent': None,
#    'id': '8b4c77ba-7e45-4207-9566-f916e108a25f'},
#   {'name': 'Environment',
#    'updated_at': '2017-04-04T09:00:07.132850Z',
#    'parent': {'name': 'Science',
#     'updated_at': '2017-04-04T09:00:06.181288Z',
#     'id': '8b4c77ba-7e45-4207-9566-f916e108a25f'},
#    'id': '7044b2ae-c3ff-4ba1-9654-68b68f37c396'},
#   {'name': 'Animals',
#    'updated_at': '2017-04-04T09:00:07.148111Z',
#    'parent': {'name': 'Science',
#     'updated_at': '2017-04-04T09:00:06.181288Z',
#     'id': '8b4c77ba-7e45-4207-9566-f916e108a25f'},
#    'id': 'a17bc424-285b-4781-9269-63ef307349d1'}],
#  'platforms': [{'slug': 'allplatforms',
#    'name': 'All Platforms',
#    'updated_at': '2017-04-03T15:57:09.459445Z',
#    'id': 'e5a289b8-01b3-41ce-92c1-3eb5a4e14bc0'}],
#  'player_code': "<iframe  id='partnerPlayer' frameborder='0' marginwidth='0' marginheight='0' scrolling='no' width='100%' height='100%' src='//player.pbs.org/partnerplayer/Mmn5jiVc3hpptQBnjoxD5Q==/?topbar=false&end=0&endscreen=true&start=0&autoplay=false' allowfullscreen></iframe>",
#  'availabilities': {'all_members': {'end': '2018-08-31T04:00:59Z',
#    'start': '2018-08-03T04:00:00Z',
#    'updated_at': '2018-07-30T15:25:22.008561Z'},
#   'station_members': {'end': '2018-08-31T04:00:59Z',
#    'start': '2018-08-03T04:00:00Z',
#    'updated_at': '2018-07-30T15:25:22.023127Z'},
#   'public': {'end': '2018-08-31T04:00:59Z',
#    'start': '2018-08-03T04:00:00Z',
#    'updated_at': '2018-07-30T15:25:21.989719Z'}},
#  'related_links': [],
#  'related_promos': [],
#  'parent_tree': {'type': 'episode',
#   'links': {'self': 'https://media.services.pbs.org/api/v1/episodes/b426d4bd-03a6-47c0-8720-86873e70664a/'},
#   'attributes': {'slug': 'curious-george-monkey-down-under',
#    'title': 'Monkey Down Under',
#    'season': {'type': 'season',
#     'links': {'self': 'https://media.services.pbs.org/api/v1/seasons/3fe74961-6ff6-4a7a-85a3-9478cf94163a/'},
#     'attributes': {'show': {'type': 'show',
#       'links': {'self': 'https://media.services.pbs.org/api/v1/shows/4c6ce6a0-fa34-44be-a667-d41ed4eedf59/'},
#       'attributes': {'slug': 'curious-george',
#        'seasons_count': 9,
#        'display_episode_number': True,
#        'franchise': None,
#        'tracking_ga_event': 'UA-4000040-2',
#        'title': 'Curious George',
#        'tracking_ga_page': ''},
#       'id': '4c6ce6a0-fa34-44be-a667-d41ed4eedf59'},
#      'title': '',
#      'ordinal': 7},
#     'id': '3fe74961-6ff6-4a7a-85a3-9478cf94163a'},
#    'ordinal': 1},
#   'id': 'b426d4bd-03a6-47c0-8720-86873e70664a'},
#  'has_captions': True,
#  'episode': {'type': 'episode',
#   'links': {'self': 'https://media.services.pbs.org/api/v1/episodes/b426d4bd-03a6-47c0-8720-86873e70664a/'},
#   'attributes': {'slug': 'curious-george-monkey-down-under',
#    'ordinal': 1,
#    'segment': 'A',
#    'title': 'Monkey Down Under',
#    'title_sortable': 'Monkey Down Under',
#    'updated_at': '2018-07-30T15:22:35.227277Z'},
#   'id': 'b426d4bd-03a6-47c0-8720-86873e70664a'},
#  'season': None,
#  'show': None,
#  'franchise': None,
#  'chapters': [],
#  'captions': {'webvtt': {'url': 'https://kids.video.cdn.pbs.org/captions/curious-george/7c54cabe-d81e-43cf-9bce-ce9fd99f2b6e/captions/aE5ypo_caption.vtt',
#    'profile': 'WebVTT'},
#   'srt': {'url': 'https://kids.video.cdn.pbs.org/captions/curious-george/7c54cabe-d81e-43cf-9bce-ce9fd99f2b6e/captions/JMum5S_caption.srt',
#    'profile': 'SRT'},
#   'dfxp': {'url': 'https://kids.video.cdn.pbs.org/captions/curious-george/7c54cabe-d81e-43cf-9bce-ce9fd99f2b6e/captions/meDU3u_caption.dfxp',
#    'profile': 'DFXP'},
#   'caption-sami': {'url': 'https://kids.video.cdn.pbs.org/captions/curious-george/7c54cabe-d81e-43cf-9bce-ce9fd99f2b6e/captions/IMd3XE_caption.sami',
#    'profile': 'Caption-SAMI'}},
#  'videos': [{'url': 'https://urs.pbs.org/redirect/49812af8189743b28e40c51dcbce37b9/',
#    'profile': 'hls-16x9-1080p',
#    'format': 'hls',
#    'ratio': '16x9',
#    'bitrate': '1080p'},
#   {'url': 'https://urs.pbs.org/redirect/524ee19f6d9b4e6786595aa68fd38977/',
#    'profile': 'hls-16x9-720p',
#    'format': 'hls',
#    'ratio': '16x9',
#    'bitrate': '720p'},
#   {'url': 'https://urs.pbs.org/redirect/66c367c2b16044cb8a0f768ae2272fa3/',
#    'profile': 'mp4-16x9-baseline',
#    'format': 'mp4',
#    'ratio': '16x9',
#    'bitrate': None},
#   {'url': 'https://urs.pbs.org/redirect/7da228fb56154454afbcc8da19ac707b/',
#    'profile': 'mp4-16x9-720p',
#    'format': 'mp4',
#    'ratio': '16x9',
#    'bitrate': '720p'}],
#  'series_title': 'Curious George',
#  'series_slug': 'curious-george',
#  'series_nola': 'CUGE',
#  'supports': {'hls': True, 'mp4': True},
#  'guid': '7c54cabe-d81e-43cf-9bce-ce9fd99f2b6e',
#  'description': 'George and The Man with the Yellow Hat head to the land down under for an Australian adventure. While the Man goes sea cow sightseeing, George stays behind to investigate the creature that left a set of giant footprints in the sand. Could it be a mysterious hopping clown rabbit?',
#  'keywords': ['curious george',
#   'george',
#   'monkey down under',
#   'australia',
#   'outback',
#   'australian outback',
#   'kangaroo',
#   'kangaroos',
#   'manatees',
#   'sea cow',
#   'sea cows',
#   'animals',
#   'science',
#   'mammals',
#   'full episode',
#   'full episodes',
#   'episode',
#   'episodes'],
#  'media_id': 2365465333,
#  'nola_episode': 'CUGE701',
#  'expirationdate': '2018-08-31T04:00:59Z',
#  'availabledate': '2018-08-03T04:00:00Z'}

# %%
for video in item["videos"]:
    print("{format} {ratio} {bitrate}".format(**video))
# Out:
# hls 16x9 1080p
# hls 16x9 720p
# mp4 16x9 None
# mp4 16x9 720p
